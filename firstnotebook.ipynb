# %%
print("hello jupyter")
# Out:
# hello jupyter

# %%
name=input("enter your name")
print(name)

# %% [markdown]
# #Below is a plot example

# %%
import matplotlib.pyplot as plt
plt.plot([0,8,4,8,9],[2,8,7,5,3])
plt.plot([0,8,3,8,9],[2,4,7,5,3])
plt.plot([0,8,4,6,9],[2,8,3,5,3])
plt.plot([8,8,4,8,9],[2,8,7,5,3])
plt.show()
